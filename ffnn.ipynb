# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
cancer_dir = "data/unhealthy"
normal_dir = "data/healthy"

# %%
filepaths = []
labels = []
for label, folder in zip(['cancer', 'normal'], [cancer_dir, normal_dir]):
    for file in os.listdir(folder):
        filepaths.append(os.path.join(folder, file))
        labels.append(label)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})

# %%
print(df['labels'].value_counts())
sns.countplot(data=df, x='labels', palette='viridis')
plt.title("Class Distribution")
plt.show()
# Out:
# labels
# cancer    5504
# normal    4008
# Name: count, dtype: int64
# C:\Users\jayat\AppData\Local\Temp\ipykernel_4592\1013014196.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='labels', palette='viridis')

# %%
plt.figure(figsize=(12, 8))
for i in range(20):
    random_idx = np.random.randint(len(df))
    img = cv2.imread(df['filepaths'].iloc[random_idx])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(4, 5, i + 1)
    plt.imshow(img)
    plt.title(df['labels'].iloc[random_idx])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
img_size = 150
X = []
y = []
for i, row in df.iterrows():
    img = cv2.imread(row['filepaths'], cv2.IMREAD_GRAYSCALE)
    resized_img = cv2.resize(img, (img_size, img_size))
    X.append(resized_img)
    y.append(0 if row['labels'] == 'normal' else 1)

X = np.array(X) / 255.0 
X = X.reshape(-1, img_size * img_size)
y = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

y_train_cat = to_categorical(y_train, num_classes=2)
y_val_cat = to_categorical(y_val, num_classes=2)
y_test_cat = to_categorical(y_test, num_classes=2)

# %%
ffnn_model = Sequential([
    Dense(256, activation='relu', input_shape=(img_size * img_size,)),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])
# Out:
# d:\Projects\Bilstrim and other 4 models\env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ffnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = ffnn_model.fit(X_train, y_train_cat, validation_data=(X_val, y_val_cat), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.5386 - loss: 5.2386 - val_accuracy: 0.5788 - val_loss: 0.6760
# Epoch 2/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5870 - loss: 0.6903 - val_accuracy: 0.5788 - val_loss: 0.6696
# Epoch 3/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5790 - loss: 0.7171 - val_accuracy: 0.5788 - val_loss: 0.6767
# Epoch 4/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5808 - loss: 0.6787 - val_accuracy: 0.5788 - val_loss: 0.6731
# Epoch 5/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5669 - loss: 0.6764 - val_accuracy: 0.5788 - val_loss: 0.6695
# Epoch 6/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5755 - loss: 0.6639 - val_accuracy: 0.5788 - val_loss: 0.6622
# Epoch 7/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5870 - loss: 0.6472 - val_accuracy: 0.5788 - val_loss: 0.6505
# Epoch 8/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5718 - loss: 0.6458 - val_accuracy: 0.5788 - val_loss: 0.6585
# Epoch 9/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5749 - loss: 0.6430 - val_accuracy: 0.5788 - val_loss: 0.6560
# Epoch 10/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5775 - loss: 0.6276 - val_accuracy: 0.5788 - val_loss: 0.6705
# Epoch 11/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5709 - loss: 0.6299 - val_accuracy: 0.5788 - val_loss: 0.6560
# Epoch 12/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.5837 - loss: 0.6161 - val_accuracy: 0.5788 - val_loss: 0.6478
# Epoch 13/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5689 - loss: 0.6178 - val_accuracy: 0.5788 - val_loss: 0.6693
# Epoch 14/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5789 - loss: 0.6173 - val_accuracy: 0.5788 - val_loss: 0.6516
# Epoch 15/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.5788 - loss: 0.6203 - val_accuracy: 0.5788 - val_loss: 0.6670
# Epoch 16/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.5751 - loss: 0.6229 - val_accuracy: 0.5788 - val_loss: 0.6505
# Epoch 17/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5769 - loss: 0.6132 - val_accuracy: 0.5788 - val_loss: 0.6484
# Epoch 18/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5802 - loss: 0.5997 - val_accuracy: 0.5788 - val_loss: 0.6581
# Epoch 19/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5862 - loss: 0.6008 - val_accuracy: 0.5788 - val_loss: 0.6693
# Epoch 20/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5819 - loss: 0.5947 - val_accuracy: 0.5916 - val_loss: 0.6893
# Epoch 21/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5876 - loss: 0.5833 - val_accuracy: 0.5751 - val_loss: 0.6843
# Epoch 22/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5958 - loss: 0.5898 - val_accuracy: 0.5961 - val_loss: 0.6892
# Epoch 23/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6037 - loss: 0.5768 - val_accuracy: 0.6014 - val_loss: 0.6987
# Epoch 24/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6155 - loss: 0.5737 - val_accuracy: 0.5923 - val_loss: 0.7163
# Epoch 25/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6169 - loss: 0.5761 - val_accuracy: 0.5998 - val_loss: 0.7400
# Epoch 26/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6007 - loss: 0.5710 - val_accuracy: 0.5886 - val_loss: 0.7748
# Epoch 27/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6171 - loss: 0.5671 - val_accuracy: 0.5901 - val_loss: 0.7499
# Epoch 28/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6260 - loss: 0.5737 - val_accuracy: 0.5976 - val_loss: 0.7602
# Epoch 29/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6281 - loss: 0.5597 - val_accuracy: 0.5563 - val_loss: 0.6995
# Epoch 30/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6151 - loss: 0.5740 - val_accuracy: 0.5736 - val_loss: 0.7189
# Epoch 31/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6238 - loss: 0.5674 - val_accuracy: 0.6089 - val_loss: 0.7412
# Epoch 32/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6520 - loss: 0.5538 - val_accuracy: 0.6134 - val_loss: 0.7367
# Epoch 33/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6364 - loss: 0.5491 - val_accuracy: 0.5938 - val_loss: 0.7386
# Epoch 34/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6355 - loss: 0.5560 - val_accuracy: 0.6059 - val_loss: 0.7272
# Epoch 35/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6400 - loss: 0.5438 - val_accuracy: 0.5953 - val_loss: 0.7529
# Epoch 36/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.6311 - loss: 0.5449 - val_accuracy: 0.5946 - val_loss: 0.7189
# Epoch 37/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6282 - loss: 0.5519 - val_accuracy: 0.6006 - val_loss: 0.7562
# Epoch 38/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6249 - loss: 0.5599 - val_accuracy: 0.6216 - val_loss: 0.7694
# Epoch 39/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6339 - loss: 0.5472 - val_accuracy: 0.6096 - val_loss: 0.7648
# Epoch 40/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6376 - loss: 0.5525 - val_accuracy: 0.6029 - val_loss: 0.7714
# Epoch 41/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.6394 - loss: 0.5470 - val_accuracy: 0.5938 - val_loss: 0.6960
# Epoch 42/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6302 - loss: 0.5629 - val_accuracy: 0.5983 - val_loss: 0.7488
# Epoch 43/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6442 - loss: 0.5365 - val_accuracy: 0.6171 - val_loss: 0.8045
# Epoch 44/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6549 - loss: 0.5331 - val_accuracy: 0.6171 - val_loss: 0.7653
# Epoch 45/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6536 - loss: 0.5379 - val_accuracy: 0.6104 - val_loss: 0.7419
# Epoch 46/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6415 - loss: 0.5442 - val_accuracy: 0.5908 - val_loss: 0.7252
# Epoch 47/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6295 - loss: 0.5559 - val_accuracy: 0.6141 - val_loss: 0.8199
# Epoch 48/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6486 - loss: 0.5455 - val_accuracy: 0.6119 - val_loss: 0.7434
# Epoch 49/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6405 - loss: 0.5437 - val_accuracy: 0.6209 - val_loss: 0.7636
# Epoch 50/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6434 - loss: 0.5529 - val_accuracy: 0.5788 - val_loss: 0.7591

# %%
test_loss, test_accuracy = ffnn_model.evaluate(X_test, y_test_cat)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6077 - loss: 0.7170
# Test Accuracy: 0.61

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_pred_probs = ffnn_model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples', xticklabels=['Normal', 'Cancer'], yticklabels=['Normal', 'Cancer'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
print(classification_report(y_test, y_pred, target_names=['Normal', 'Cancer']))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.52      0.91      0.66      1203
#       Cancer       0.86      0.40      0.54      1651
#
#     accuracy                           0.61      2854
#    macro avg       0.69      0.65      0.60      2854
# weighted avg       0.72      0.61      0.59      2854
